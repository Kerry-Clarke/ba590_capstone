# %%
import numpy as np
import pandas as pd

# %%
df14 = pd.read_excel('data/Apps_2014_15.xlsx', sheet_name='Admissions Tab - MASTER')
df14.head()
# Out:
#        ID Active Region ADMIT_TYPE           ADMT_DESC  DEC        APP_DESC  \
# 0  135594            NY         FY  Freshman Applicant   A1           Admit
# 1  136110            NY         FY  Freshman Applicant   A7            Deny
# 2  136113            NY         FY  Freshman Applicant   A1           Admit
# 3  135572            CT         FY  Freshman Applicant  NaN             NaN
# 4  135579           NaN         FY  Freshman Applicant   A2  Admit Withdraw
#
#   COMP  APP_ENTRY_TERM COLLEGE_CODE DEGREE_TYPE      ...        ACT  \
# 0    Y          201409           AS          BA      ...       28.0
# 1    Y          201409           AS          BA      ...       22.0
# 2    Y          201409           AS          BA      ...       31.0
# 3    N          201409           NS          BS      ...        NaN
# 4    Y          201409           BU          BS      ...        NaN
#
#   SAT Math OLD SAT Verbal OLD SAT WRI OLD  Total SAT OLD Class Percentile  \
# 0          NaN            NaN         NaN            NaN              NaN
# 1          NaN            NaN         NaN            NaN              NaN
# 2          NaN            NaN         NaN            NaN              NaN
# 3          NaN            NaN         NaN            NaN              NaN
# 4          NaN            NaN         NaN            NaN              NaN
#
#            Citizen_Category Legacy                       Ethnicity  \
# 0                   Citizen    NaN  White,Including Spain/Portugal
# 1                   Citizen    NaN  White,Including Spain/Portugal
# 2                   Citizen    NaN  White,Including Spain/Portugal
# 3  Permanent Resident Alien    NaN                           Asian
# 4                   Foreign    NaN      International/No ethnicity
#
#   Test Optional
# 0             N
# 1             N
# 2             N
# 3             N
# 4             N
#
# [5 rows x 33 columns]

# %%
df14.columns
# Out:
# Index(['ID', 'Active Region', 'ADMIT_TYPE', 'ADMT_DESC', 'DEC', 'APP_DESC',
#        'COMP', 'APP_ENTRY_TERM', 'COLLEGE_CODE', 'DEGREE_TYPE', 'MAJOR_CODE',
#        'RESIDENT_CODE', 'ACCP', 'CONF', 'ENROLL', 'JESUIT', 'HSCity', 'HST',
#        'HSNATION', 'Sex', 'RELIGION', 'APPLIED', '1ST GEN', 'ACT',
#        'SAT Math OLD', 'SAT Verbal OLD', 'SAT WRI OLD', 'Total SAT OLD',
#        'Class Percentile', 'Citizen_Category', 'Legacy', 'Ethnicity',
#        'Test Optional'],
#       dtype='object')

# %%
df15 = pd.read_excel('data/Apps_2015_16.xlsx', sheet_name='All Apps')
df15.head()
# Out:
#        ID          HSCity  HST College Code                       College  \
# 0  154306          Hurley   NY           AS  College of Arts and Sciences
# 1  156038      Faisalabad  NaN           BU      Dolan School of Business
# 2  154625       Islamabad  NaN           EG         School of Engineering
# 3  148401       Manhasset   NY           AS  College of Arts and Sciences
# 4  149482  South Hamilton   MA           AS  College of Arts and Sciences
#
#    MAJR 1ST GEN  RGPA  Rating   P_M   ...   Active Postal Active Country  \
# 0  BIOL       N  3.11     5.0   NaN   ...      12449-5010  United States
# 1  INBU       Y   NaN     NaN   NaN   ...           38000       Pakistan
# 2  MEEN       Y   NaN     NaN   NaN   ...           44000       Pakistan
# 3  0000       N  3.67     4.0   NaN   ...      11563-1952  United States
# 4  0000       N  2.86     7.0  PLUS   ...      01982-2254  United States
#
#   Ethnicity Code Ethnicity Test Optional Total SAT OLD SAT Verbal OLD  \
# 0              W     White             N           NaN            NaN
# 1              F   Foreign           TOP           NaN            NaN
# 2              F   Foreign           TOP           NaN            NaN
# 3              U   Unknown           TOP           NaN            NaN
# 4              W     White             N        1760.0          610.0
#
#   SAT Math OLD  SAT WRI OLD  Legacy
# 0          NaN          NaN     NaN
# 1          NaN          NaN     NaN
# 2          NaN          NaN     NaN
# 3          NaN          NaN       N
# 4        530.0        620.0       N
#
# [5 rows x 33 columns]

# %%
df15.columns
# Out:
# Index(['ID', 'HSCity', 'HST', 'College Code', 'College', 'MAJR', '1ST GEN',
#        'RGPA', 'Rating', 'P_M', 'Merit', 'DEC', 'APP_DESC', 'ACCP', 'CONF',
#        'Citizen', 'Sex', 'RES', 'ACT', 'Class Rank', 'Class Size',
#        'Active City', 'Active Region', 'Active Postal', 'Active Country',
#        'Ethnicity Code', 'Ethnicity', 'Test Optional', 'Total SAT OLD',
#        'SAT Verbal OLD', 'SAT Math OLD', 'SAT WRI OLD', 'Legacy'],
#       dtype='object')

# %%
df16 = pd.read_excel('data/Apps_2016_17.xlsx', sheet_name='Full Population')
df16.head()
# Out:
#        ID Accept Enroll      HSCity HST College Code  \
# 0  173714    NaN    NaN     Wolcott  CT           BU
# 1  170325    NaN    NaN     Chatham  NJ           AS
# 2  171363    NaN    NaN   NORTHPORT  NY           AS
# 3  174914    NaN    NaN    Guaynabo  PR           AS
# 4  175221    NaN    NaN  Bridgeport  CT           AS
#
#                       College  MAJR  \
# 0    Dolan School of Business  INBU
# 1  College of Arts & Sciences  VPFT
# 2  College of Arts & Sciences  COMM
# 3  College of Arts & Sciences  MLLF
# 4  College of Arts & Sciences  BIOL
#
#                            Major Description 1ST GEN  ...    Active Region  \
# 0                     International Business      34  ...               CT
# 1            Film, Television and Media Arts       N  ...               NJ
# 2                              Communication       N  ...               NY
# 3  Modern Languages and Literatures - French       N  ...               PR
# 4                                    Biology      34  ...               CT
#
#    Active Postal Active Country Ethnicity Test Optional Total SAT OLD  \
# 0     06716-2306  United States     White             N        1600.0
# 1     07928-1118  United States     White             N           NaN
# 2     11768-1939  United States     White             N        1680.0
# 3     00926-5545  United States  Hispanic             N        1500.0
# 4     06608-1046  United States  Hispanic           TOP           NaN
#
#   SAT Verbal OLD SAT Math OLD SAT WRI OLD Legacy
# 0          550.0        470.0       580.0      B
# 1            NaN          NaN         NaN    NaN
# 2          580.0        520.0       580.0    NaN
# 3          560.0        400.0       540.0    NaN
# 4            NaN          NaN         NaN    NaN
#
# [5 rows x 36 columns]

# %%
df16.columns
# Out:
# Index(['ID', 'Accept', 'Enroll', 'HSCity', 'HST', 'College Code', 'College',
#        'MAJR', 'Major Description', '1ST GEN', 'RGPA', 'Rating', 'P_M',
#        'Merit', 'DEC', 'APP_DESC', 'ACCP', 'CONF', 'Citzen', 'Sex', 'RES',
#        'ACT', 'Class Rank', 'Class Size', 'Class Percentile', 'Active City',
#        'Active Region', 'Active Postal', 'Active Country', 'Ethnicity',
#        'Test Optional', 'Total SAT OLD', 'SAT Verbal OLD', 'SAT Math OLD',
#        'SAT WRI OLD', 'Legacy'],
#       dtype='object')

# %%
df17 = pd.read_excel('data/Apps_2017_18.xlsx', sheet_name='Initial Pop - TEST OPT')
df17.head()
# Out:
#        ID Accept Enroll      HSCity HST College Code  \
# 0  194600    NaN    NaN  Bridgeport  CT           NS
# 1  192063     A1    NaN   Southwick  MA           AS
# 2  196995    NaN    NaN  Bridgeport  CT           AS
# 3  196162    NaN    NaN     Tolland  CT           EG
# 4  194619    NaN    NaN  Bridgeport  CT           NS
#
#                                     College  MAJR       Major Description  \
# 0  Egan School of Nursing & Health Sciences  NURS                 Nursing
# 1                College of Arts & Sciences  BIOL                 Biology
# 2                College of Arts & Sciences  HIST                 History
# 3                                       NaN  MEEN  Mechanical Engineering
# 4  Egan School of Nursing & Health Sciences  NURS                 Nursing
#
#   1ST GEN      ...       Total SAT OLD  SAT Verbal OLD SAT Math OLD  \
# 0      34      ...                 NaN             NaN          NaN
# 1       N      ...                 NaN             NaN          NaN
# 2       N      ...                 NaN             NaN          NaN
# 3       N      ...                 NaN             NaN          NaN
# 4       N      ...                 NaN             NaN          NaN
#
#   SAT WRI OLD Legacy SAT Critical Reading - conversion SAT Math - conversion  \
# 0         NaN    NaN                               NaN                   NaN
# 1         NaN    NaN                               NaN                   NaN
# 2         NaN    NaN                               NaN                   NaN
# 3         NaN    NaN                               NaN                   NaN
# 4         NaN    NaN                               NaN                   NaN
#
#   SAT Reading NEW SAT Math NEW SAT Total NEW
# 0             NaN          NaN           NaN
# 1           570.0        640.0        1210.0
# 2           630.0        610.0        1240.0
# 3           540.0        540.0        1080.0
# 4             NaN          NaN           NaN
#
# [5 rows x 41 columns]

# %%
df17.columns
# Out:
# Index(['ID', 'Accept', 'Enroll', 'HSCity', 'HST', 'College Code', 'College',
#        'MAJR', 'Major Description', '1ST GEN', 'RGPA', 'Rating', 'P_M',
#        'Merit', 'DEC', 'APP_DESC', 'ACCP', 'CONF', 'Citizen', 'Sex', 'RES',
#        'Class Rank', 'Class Size', 'Class Percentile', 'Active City',
#        'Active Region', 'Active Postal', 'Active Country', 'Ethnicity',
#        'Test Optional', 'ACT', 'Total SAT OLD', 'SAT Verbal OLD',
#        'SAT Math OLD', 'SAT WRI OLD', 'Legacy',
#        'SAT Critical Reading - conversion', 'SAT Math - conversion',
#        'SAT Reading NEW', 'SAT Math NEW', 'SAT Total NEW'],
#       dtype='object')

# %%
df18 = pd.read_excel('data/Apps_2018_19.xlsx', sheet_name='Apps')
df18.head()
# Out:
#        ID Accept         HSCity HST                       College  \
# 0  214717    NaN  North Eastham  MA      Dolan School of Business
# 1  214861    NaN     Bridgeport  CT      Dolan School of Business
# 2  211022    NaN         Newark  NJ      Dolan School of Business
# 3  211015    NaN       New York  NY  College of Arts and Sciences
# 4  204374    NaN        Danbury  CT      Dolan School of Business
#
#                   MAJR    Major Description 1ST GEN  RGPA  Rating  \
# 0  Business Undeclared  Business Undeclared      34  2.15     9.0
# 1            Marketing            Marketing      34  2.52     9.0
# 2            Marketing            Marketing       N  1.24     9.0
# 3           Undeclared           Undeclared       N  1.90     9.0
# 4           Management           Management      34   NaN     NaN
#
#        ...       Test Optional Legacy SAT Math OLD SAT WRI OLD SAT Verbal OLD  \
# 0      ...                 TOP    NaN          NaN         NaN            NaN
# 1      ...                   N    NaN          NaN         NaN            NaN
# 2      ...                   N    NaN          NaN         NaN            NaN
# 3      ...                 TOP    NaN          NaN         NaN            NaN
# 4      ...                   N    NaN          NaN         NaN            NaN
#
#   Total SAT OLD   ACT SAT Reading NEW SAT Math NEW  SAT Total NEW
# 0           NaN   NaN             NaN          NaN            NaN
# 1           NaN   NaN           440.0        450.0          890.0
# 2           NaN  18.0             NaN          NaN            NaN
# 3           NaN   NaN             NaN          NaN            NaN
# 4           NaN   NaN             NaN          NaN            NaN
#
# [5 rows x 37 columns]

# %%
df18.columns
# Out:
# Index(['ID', 'Accept', 'HSCity', 'HST', 'College', 'MAJR', 'Major Description',
#        '1ST GEN', 'RGPA', 'Rating', 'P_M', 'Merit', 'DEC', 'APP_DESC', 'ACCP',
#        'CONF', 'Citizen', 'Sex', 'RES', 'Class Rank', 'Class Size',
#        'Class Percentile', 'Active City', 'Active Region', 'Active Postal',
#        'Active Country', 'Ethnicity', 'Test Optional', 'Legacy',
#        'SAT Math OLD', 'SAT WRI OLD', 'SAT Verbal OLD', 'Total SAT OLD', 'ACT',
#        'SAT Reading NEW', 'SAT Math NEW', 'SAT Total NEW'],
#       dtype='object')

# %%
df = df18.append(df17, sort=False)
df.head()
# Out:
#        ID Accept         HSCity HST                       College  \
# 0  214717    NaN  North Eastham  MA      Dolan School of Business
# 1  214861    NaN     Bridgeport  CT      Dolan School of Business
# 2  211022    NaN         Newark  NJ      Dolan School of Business
# 3  211015    NaN       New York  NY  College of Arts and Sciences
# 4  204374    NaN        Danbury  CT      Dolan School of Business
#
#                   MAJR    Major Description 1ST GEN  RGPA  Rating  \
# 0  Business Undeclared  Business Undeclared      34  2.15     9.0
# 1            Marketing            Marketing      34  2.52     9.0
# 2            Marketing            Marketing       N  1.24     9.0
# 3           Undeclared           Undeclared       N  1.90     9.0
# 4           Management           Management      34   NaN     NaN
#
#            ...           SAT Verbal OLD Total SAT OLD   ACT SAT Reading NEW  \
# 0          ...                      NaN           NaN   NaN             NaN
# 1          ...                      NaN           NaN   NaN           440.0
# 2          ...                      NaN           NaN  18.0             NaN
# 3          ...                      NaN           NaN   NaN             NaN
# 4          ...                      NaN           NaN   NaN             NaN
#
#   SAT Math NEW SAT Total NEW Enroll College Code  \
# 0          NaN           NaN    NaN          NaN
# 1        450.0         890.0    NaN          NaN
# 2          NaN           NaN    NaN          NaN
# 3          NaN           NaN    NaN          NaN
# 4          NaN           NaN    NaN          NaN
#
#   SAT Critical Reading - conversion  SAT Math - conversion
# 0                               NaN                    NaN
# 1                               NaN                    NaN
# 2                               NaN                    NaN
# 3                               NaN                    NaN
# 4                               NaN                    NaN
#
# [5 rows x 41 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22579 entries, 0 to 11217
# Data columns (total 41 columns):
# ID                                   22579 non-null int64
# Accept                               13645 non-null object
# HSCity                               22513 non-null object
# HST                                  21919 non-null object
# College                              22578 non-null object
# MAJR                                 22579 non-null object
# Major Description                    22511 non-null object
# 1ST GEN                              22579 non-null object
# RGPA                                 21016 non-null float64
# Rating                               21472 non-null float64
# P_M                                  11036 non-null object
# Merit                                13226 non-null object
# DEC                                  21592 non-null object
# APP_DESC                             21592 non-null object
# ACCP                                 13645 non-null object
# CONF                                 2094 non-null object
# Citizen                              22579 non-null object
# Sex                                  22579 non-null object
# RES                                  22579 non-null object
# Class Rank                           3332 non-null float64
# Class Size                           3331 non-null float64
# Class Percentile                     3331 non-null float64
# Active City                          22574 non-null object
# Active Region                        22304 non-null object
# Active Postal                        22408 non-null object
# Active Country                       22574 non-null object
# Ethnicity                            22579 non-null object
# Test Optional                        22579 non-null object
# Legacy                               1488 non-null object
# SAT Math OLD                         919 non-null float64
# SAT WRI OLD                          917 non-null float64
# SAT Verbal OLD                       919 non-null float64
# Total SAT OLD                        915 non-null float64
# ACT                                  5379 non-null float64
# SAT Reading NEW                      11451 non-null float64
# SAT Math NEW                         11451 non-null float64
# SAT Total NEW                        11451 non-null float64
# Enroll                               994 non-null object
# College Code                         11218 non-null object
# SAT Critical Reading - conversion    905 non-null float64
# SAT Math - conversion                905 non-null float64
# dtypes: float64(15), int64(1), object(25)
# memory usage: 7.2+ MB

# %%
df = df.append(df16, sort=False)
df.head()
# Out:
#        ID Accept         HSCity HST                       College  \
# 0  214717    NaN  North Eastham  MA      Dolan School of Business
# 1  214861    NaN     Bridgeport  CT      Dolan School of Business
# 2  211022    NaN         Newark  NJ      Dolan School of Business
# 3  211015    NaN       New York  NY  College of Arts and Sciences
# 4  204374    NaN        Danbury  CT      Dolan School of Business
#
#                   MAJR    Major Description 1ST GEN  RGPA  Rating   ...    \
# 0  Business Undeclared  Business Undeclared      34  2.15     9.0   ...
# 1            Marketing            Marketing      34  2.52     9.0   ...
# 2            Marketing            Marketing       N  1.24     9.0   ...
# 3           Undeclared           Undeclared       N  1.90     9.0   ...
# 4           Management           Management      34   NaN     NaN   ...
#
#   Total SAT OLD   ACT SAT Reading NEW SAT Math NEW SAT Total NEW Enroll  \
# 0           NaN   NaN             NaN          NaN           NaN    NaN
# 1           NaN   NaN           440.0        450.0         890.0    NaN
# 2           NaN  18.0             NaN          NaN           NaN    NaN
# 3           NaN   NaN             NaN          NaN           NaN    NaN
# 4           NaN   NaN             NaN          NaN           NaN    NaN
#
#   College Code SAT Critical Reading - conversion SAT Math - conversion  Citzen
# 0          NaN                               NaN                   NaN     NaN
# 1          NaN                               NaN                   NaN     NaN
# 2          NaN                               NaN                   NaN     NaN
# 3          NaN                               NaN                   NaN     NaN
# 4          NaN                               NaN                   NaN     NaN
#
# [5 rows x 42 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33634 entries, 0 to 11054
# Data columns (total 42 columns):
# ID                                   33634 non-null int64
# Accept                               20440 non-null object
# HSCity                               33547 non-null object
# HST                                  32700 non-null object
# College                              33633 non-null object
# MAJR                                 33634 non-null object
# Major Description                    33566 non-null object
# 1ST GEN                              33633 non-null object
# RGPA                                 31211 non-null float64
# Rating                               31859 non-null float64
# P_M                                  17045 non-null object
# Merit                                19786 non-null object
# DEC                                  32124 non-null object
# APP_DESC                             32124 non-null object
# ACCP                                 20440 non-null object
# CONF                                 3152 non-null object
# Citizen                              22579 non-null object
# Sex                                  33634 non-null object
# RES                                  33634 non-null object
# Class Rank                           5066 non-null float64
# Class Size                           5065 non-null float64
# Class Percentile                     5065 non-null float64
# Active City                          33628 non-null object
# Active Region                        33186 non-null object
# Active Postal                        33390 non-null object
# Active Country                       33628 non-null object
# Ethnicity                            33634 non-null object
# Test Optional                        33634 non-null object
# Legacy                               2160 non-null object
# SAT Math OLD                         6278 non-null float64
# SAT WRI OLD                          6276 non-null float64
# SAT Verbal OLD                       6278 non-null float64
# Total SAT OLD                        6274 non-null float64
# ACT                                  8196 non-null float64
# SAT Reading NEW                      11451 non-null float64
# SAT Math NEW                         11451 non-null float64
# SAT Total NEW                        11451 non-null float64
# Enroll                               2052 non-null object
# College Code                         22273 non-null object
# SAT Critical Reading - conversion    905 non-null float64
# SAT Math - conversion                905 non-null float64
# Citzen                               11055 non-null object
# dtypes: float64(15), int64(1), object(26)
# memory usage: 11.0+ MB

# %%
df = df.append(df15, sort=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44401 entries, 0 to 10766
# Data columns (total 43 columns):
# ID                                   44401 non-null int64
# Accept                               20440 non-null object
# HSCity                               44282 non-null object
# HST                                  43220 non-null object
# College                              44400 non-null object
# MAJR                                 44401 non-null object
# Major Description                    33566 non-null object
# 1ST GEN                              44396 non-null object
# RGPA                                 41233 non-null float64
# Rating                               42016 non-null float64
# P_M                                  22975 non-null object
# Merit                                26423 non-null object
# DEC                                  42396 non-null object
# APP_DESC                             42396 non-null object
# ACCP                                 27368 non-null object
# CONF                                 4118 non-null object
# Citizen                              33345 non-null object
# Sex                                  44401 non-null object
# RES                                  44400 non-null object
# Class Rank                           7530 non-null float64
# Class Size                           7529 non-null float64
# Class Percentile                     5065 non-null float64
# Active City                          44393 non-null object
# Active Region                        43839 non-null object
# Active Postal                        44068 non-null object
# Active Country                       44393 non-null object
# Ethnicity                            44179 non-null object
# Test Optional                        44401 non-null object
# Legacy                               8456 non-null object
# SAT Math OLD                         12016 non-null float64
# SAT WRI OLD                          12014 non-null float64
# SAT Verbal OLD                       12016 non-null float64
# Total SAT OLD                        12012 non-null float64
# ACT                                  10730 non-null float64
# SAT Reading NEW                      11451 non-null float64
# SAT Math NEW                         11451 non-null float64
# SAT Total NEW                        11451 non-null float64
# Enroll                               2052 non-null object
# College Code                         33040 non-null object
# SAT Critical Reading - conversion    905 non-null float64
# SAT Math - conversion                905 non-null float64
# Citzen                               11055 non-null object
# Ethnicity Code                       10767 non-null object
# dtypes: float64(15), int64(1), object(27)
# memory usage: 14.9+ MB

# %%
df = df.append(df14, sort=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54379 entries, 0 to 9977
# Data columns (total 57 columns):
# ID                                   54379 non-null int64
# Accept                               20440 non-null object
# HSCity                               54217 non-null object
# HST                                  52927 non-null object
# College                              44400 non-null object
# MAJR                                 44401 non-null object
# Major Description                    33566 non-null object
# 1ST GEN                              46296 non-null object
# RGPA                                 41233 non-null float64
# Rating                               42016 non-null float64
# P_M                                  22975 non-null object
# Merit                                26423 non-null object
# DEC                                  51989 non-null object
# APP_DESC                             51989 non-null object
# ACCP                                 34505 non-null object
# CONF                                 5174 non-null object
# Citizen                              33345 non-null object
# Sex                                  54379 non-null object
# RES                                  44400 non-null object
# Class Rank                           7530 non-null float64
# Class Size                           7529 non-null float64
# Class Percentile                     6904 non-null float64
# Active City                          44393 non-null object
# Active Region                        53545 non-null object
# Active Postal                        44068 non-null object
# Active Country                       44393 non-null object
# Ethnicity                            54118 non-null object
# Test Optional                        54379 non-null object
# Legacy                               9018 non-null object
# SAT Math OLD                         17616 non-null float64
# SAT WRI OLD                          17614 non-null float64
# SAT Verbal OLD                       17616 non-null float64
# Total SAT OLD                        17612 non-null float64
# ACT                                  12899 non-null float64
# SAT Reading NEW                      11451 non-null float64
# SAT Math NEW                         11451 non-null float64
# SAT Total NEW                        11451 non-null float64
# Enroll                               2052 non-null object
# College Code                         33040 non-null object
# SAT Critical Reading - conversion    905 non-null float64
# SAT Math - conversion                905 non-null float64
# Citzen                               11055 non-null object
# Ethnicity Code                       10767 non-null object
# ADMIT_TYPE                           9978 non-null object
# ADMT_DESC                            9978 non-null object
# COMP                                 9978 non-null object
# APP_ENTRY_TERM                       9978 non-null float64
# COLLEGE_CODE                         9977 non-null object
# DEGREE_TYPE                          9977 non-null object
# MAJOR_CODE                           9977 non-null object
# RESIDENT_CODE                        9978 non-null object
# ENROLL                               0 non-null float64
# JESUIT                               512 non-null object
# HSNATION                             228 non-null object
# RELIGION                             9166 non-null object
# APPLIED                              9978 non-null object
# Citizen_Category                     9974 non-null object
# dtypes: float64(17), int64(1), object(39)
# memory usage: 24.1+ MB

# %%
df.to_csv('data/admission_master.csv', index=0)

# %%
df = pd.read_csv('data/admission_master.csv', low_memory=False)
df.head()
# Out:
#        ID Accept         HSCity HST                       College  \
# 0  214717    NaN  North Eastham  MA      Dolan School of Business
# 1  214861    NaN     Bridgeport  CT      Dolan School of Business
# 2  211022    NaN         Newark  NJ      Dolan School of Business
# 3  211015    NaN       New York  NY  College of Arts and Sciences
# 4  204374    NaN        Danbury  CT      Dolan School of Business
#
#                   MAJR    Major Description 1ST GEN  RGPA  Rating  \
# 0  Business Undeclared  Business Undeclared      34  2.15     9.0
# 1            Marketing            Marketing      34  2.52     9.0
# 2            Marketing            Marketing       N  1.24     9.0
# 3           Undeclared           Undeclared       N  1.90     9.0
# 4           Management           Management      34   NaN     NaN
#
#          ...        COLLEGE_CODE DEGREE_TYPE MAJOR_CODE RESIDENT_CODE ENROLL  \
# 0        ...                 NaN         NaN        NaN           NaN    NaN
# 1        ...                 NaN         NaN        NaN           NaN    NaN
# 2        ...                 NaN         NaN        NaN           NaN    NaN
# 3        ...                 NaN         NaN        NaN           NaN    NaN
# 4        ...                 NaN         NaN        NaN           NaN    NaN
#
#   JESUIT HSNATION RELIGION APPLIED  Citizen_Category
# 0    NaN      NaN      NaN     NaN               NaN
# 1    NaN      NaN      NaN     NaN               NaN
# 2    NaN      NaN      NaN     NaN               NaN
# 3    NaN      NaN      NaN     NaN               NaN
# 4    NaN      NaN      NaN     NaN               NaN
#
# [5 rows x 57 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54379 entries, 0 to 54378
# Data columns (total 57 columns):
# ID                                   54379 non-null int64
# Accept                               20440 non-null object
# HSCity                               54217 non-null object
# HST                                  52927 non-null object
# College                              44400 non-null object
# MAJR                                 44401 non-null object
# Major Description                    33566 non-null object
# 1ST GEN                              46296 non-null object
# RGPA                                 41233 non-null float64
# Rating                               42016 non-null float64
# P_M                                  22975 non-null object
# Merit                                26423 non-null object
# DEC                                  51989 non-null object
# APP_DESC                             51989 non-null object
# ACCP                                 34505 non-null object
# CONF                                 5174 non-null object
# Citizen                              33345 non-null object
# Sex                                  54379 non-null object
# RES                                  44400 non-null object
# Class Rank                           7530 non-null float64
# Class Size                           7529 non-null float64
# Class Percentile                     6904 non-null float64
# Active City                          44393 non-null object
# Active Region                        53545 non-null object
# Active Postal                        44068 non-null object
# Active Country                       44393 non-null object
# Ethnicity                            54118 non-null object
# Test Optional                        54379 non-null object
# Legacy                               9018 non-null object
# SAT Math OLD                         17616 non-null float64
# SAT WRI OLD                          17614 non-null float64
# SAT Verbal OLD                       17616 non-null float64
# Total SAT OLD                        17612 non-null float64
# ACT                                  12899 non-null float64
# SAT Reading NEW                      11451 non-null float64
# SAT Math NEW                         11451 non-null float64
# SAT Total NEW                        11451 non-null float64
# Enroll                               2052 non-null object
# College Code                         33040 non-null object
# SAT Critical Reading - conversion    905 non-null float64
# SAT Math - conversion                905 non-null float64
# Citzen                               11055 non-null object
# Ethnicity Code                       10767 non-null object
# ADMIT_TYPE                           9978 non-null object
# ADMT_DESC                            9978 non-null object
# COMP                                 9978 non-null object
# APP_ENTRY_TERM                       9978 non-null float64
# COLLEGE_CODE                         9977 non-null object
# DEGREE_TYPE                          9977 non-null object
# MAJOR_CODE                           9977 non-null object
# RESIDENT_CODE                        9978 non-null object
# ENROLL                               0 non-null float64
# JESUIT                               512 non-null object
# HSNATION                             228 non-null object
# RELIGION                             9166 non-null object
# APPLIED                              9978 non-null object
# Citizen_Category                     9974 non-null object
# dtypes: float64(17), int64(1), object(39)
# memory usage: 23.6+ MB
