# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
import seaborn as sns
sns.set(style="darkgrid")

# %%
# specific population is the students who meet the following criteria:
    # - are/were undergraduates
    # - the "term indicator" = Fall
    # - classified as FR (Freshmen)
    # - their cohort was 201409F, 201509F, 201609F, 201709F or 201809F
    # - were/are degree-seeking
# This population excludes any students whose initial term was not in the Fall (transfers) 

df = pd.read_excel('data/Census.xlsx', sheet_name='2014-2018')
df.head()
# Out:
#      SID     ID FIRST_NAME LAST_NAME Academic Term  Initial Term  \
# 0  10416  10416      Caleb    Blagys       2015-16        201509
# 1  10417  10417      Dylan   Freeman       2015-16        201509
# 2  21783  21783    Brandon     Russo       2014-15        201409
# 3  57992  57992      Annie     Huber       2015-16        201509
# 4  61271  61271     Hunter  Campbell       2016-17        201609
#
#   Term Indicator   Cohort             Ethnicity Students of Color Indicator  \
# 0           Fall  201509F                 White       Non-Students of Color
# 1           Fall  201509F                 White       Non-Students of Color
# 2           Fall  201409F                 White       Non-Students of Color
# 3           Fall  201509F                 White       Non-Students of Color
# 4           Fall  201609F  Hispanic of any Race           Students of Color
#
#      ...    SAT Math (old) SAT Verbal (old) SAT Writing (old)  SAT Comp (old)  \
# 0    ...             580.0            550.0             560.0          1130.0
# 1    ...               NaN              NaN               NaN             NaN
# 2    ...             600.0            420.0             450.0          1020.0
# 3    ...             520.0            580.0             580.0          1100.0
# 4    ...               NaN              NaN               NaN             NaN
#
#   Admission Rating  IR Score High School GPA HS Zip  HS Type First_Gen
# 0                7  0.521500            2.79  06430  Private         0
# 1                7  0.456947            2.23  06430  Private         0
# 2                6  0.620750            3.42  06497      NaN         0
# 3                4  0.725000            3.35  06824   Public         1
# 4                4  0.739118            3.40  06824   Public         0
#
# [5 rows x 50 columns]

# %%
df.columns, df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4927 entries, 0 to 4926
# Data columns (total 50 columns):
# SID                                           4927 non-null int64
# ID                                            4927 non-null int64
# FIRST_NAME                                    4927 non-null object
# LAST_NAME                                     4927 non-null object
# Academic Term                                 4927 non-null object
# Initial Term                                  4927 non-null int64
# Term Indicator                                4927 non-null object
# Cohort                                        4927 non-null object
# Ethnicity                                     4927 non-null object
# Students of Color Indicator                   4927 non-null object
# SEX                                           4927 non-null object
# CITY                                          4927 non-null object
# STATE                                         4898 non-null object
# ZIP                                           4915 non-null float64
# COUNTRY                                       117 non-null object
# NATN                                          105 non-null object
# CITIZEN                                       4927 non-null object
# Level of Student                              4927 non-null object
# REGHRS                                        4927 non-null int64
# FT / PT                                       4927 non-null object
# Major Complete                                4927 non-null object
# Major CIP Code                                4927 non-null int64
# Department                                    4927 non-null object
# Degree Seeking                                4927 non-null object
# Degree                                        4927 non-null object
# College Final                                 4927 non-null object
# Earned Hours                                  4927 non-null int64
# Transfer Credits                              4927 non-null int64
# Total Earned Hours                            4927 non-null int64
# ACYR                                          4927 non-null int64
# Classification - ITS                          4927 non-null object
# Earned Hours (end of 1st semester FR year)    4927 non-null int64
# GPA (end of 1st semester FR year)             4893 non-null float64
# Residency                                     4927 non-null object
# Athlete - Indicator                           4927 non-null int64
# Test Optional                                 4927 non-null object
# ACT                                           1091 non-null float64
# SAT Critical Reading (new)                    2394 non-null float64
# SAT Math (new)                                2394 non-null float64
# SAT Comp (new)                                2394 non-null float64
# SAT Math (old)                                1491 non-null float64
# SAT Verbal (old)                              1491 non-null float64
# SAT Writing (old)                             1491 non-null float64
# SAT Comp (old)                                1491 non-null float64
# Admission Rating                              4927 non-null int64
# IR Score                                      4927 non-null float64
# High School GPA                               4613 non-null float64
# HS Zip                                        4850 non-null object
# HS Type                                       4369 non-null object
# First_Gen                                     4927 non-null int64
# dtypes: float64(12), int64(13), object(25)
# memory usage: 1.9+ MB
# (Index(['SID', 'ID', 'FIRST_NAME', 'LAST_NAME', 'Academic Term', 'Initial Term',
#         'Term Indicator', 'Cohort', 'Ethnicity', 'Students of Color Indicator',
#         'SEX', 'CITY', 'STATE', 'ZIP', 'COUNTRY', 'NATN', 'CITIZEN',
#         'Level of Student', 'REGHRS', 'FT / PT', 'Major Complete',
#         'Major CIP Code', 'Department', 'Degree Seeking', 'Degree',
#         'College Final', 'Earned Hours', 'Transfer Credits',
#         'Total Earned Hours', 'ACYR', 'Classification - ITS',
#         'Earned Hours (end of 1st semester FR year)',
#         'GPA (end of 1st semester FR year)', 'Residency', 'Athlete - Indicator',
#         'Test Optional', 'ACT', 'SAT Critical Reading (new)', 'SAT Math (new)',
#         'SAT Comp (new)', 'SAT Math (old)', 'SAT Verbal (old)',
#         'SAT Writing (old)', 'SAT Comp (old)', 'Admission Rating', 'IR Score',
#         'High School GPA', 'HS Zip', 'HS Type', 'First_Gen'],
#        dtype='object'), None)

# %%
# graphs demographic features 
fig = plt.figure(figsize=(20,15))
plt.tight_layout()

ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

ax1 = sns.countplot(x=df['SEX'], data=df, palette='Set1', ax=ax1)
ax2 = sns.countplot(x=df['Residency'], data=df, palette='Set1', ax=ax2)
ax3 = sns.countplot(x=df['Athlete - Indicator'], data=df, palette='Set1', ax=ax3)
ax4 = sns.countplot(x=df['First_Gen'], data=df, palette='Set1', ax=ax4)

ax1.set_title('Student Gender')
ax2.set_title('Residency Status')
ax3.set_title('Athlete Status')
ax4.set_title('First Generation')

ax1.set_ylabel('Number of Students')
ax2.set_ylabel('Number of Students')
ax3.set_ylabel('Number of Students')
ax4.set_ylabel('Number of Students')

plt.savefig('images/gender_res_athlete_firstgen.png')

# %%
# ethnicity
fig = plt.figure(figsize=(8,6))
df['Ethnicity'].value_counts().plot(kind='bar')
plt.title('Student Ethnicity 2014-2018')
plt.show()
plt.savefig('images/ethnicity.png')

# %%
# state
fig = plt.figure(figsize=(20,5))
df['STATE'].value_counts().plot(kind='bar')
plt.title('Student Home States 2014-2018')
plt.xticks(rotation='horizontal')
plt.show()
plt.savefig('images/state.png')

# %%
# admission rating 
fig = plt.figure(figsize=(8,6))
df['Admission Rating'].value_counts().plot(kind='bar')
plt.title('Student Admission Rating 2014-2018')
plt.show()
plt.savefig('images/admission rating bar.png')

# %%
# admission rating
fig = plt.figure(figsize=(8,6))
df['Admission Rating'].plot(kind='hist')
plt.title('Student Admission Rating 2014-2018')
plt.show()
plt.savefig('images/admission rating histogram.png')

# %%
# colleges
fig = plt.figure(figsize=(8,6))
df['College Final'].value_counts().plot(kind='bar')
plt.title('Colleges 2014-2018')
plt.show()
plt.savefig('images/college.png')

# %%
# majors
fig = plt.figure(figsize=(20,5))
df['Major Complete'].value_counts().plot(kind='bar')
plt.title('Student Majors 2014-2018')
plt.show()
plt.savefig('images/majors.png')

# %%
# HS GPA and Fall Semester Freshman Year GPA 
fig = plt.figure(figsize=(15,5))
plt.tight_layout()

ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.hist(df['High School GPA'])
ax2.hist(df['GPA (end of 1st semester FR year)'])

ax1.set_title('High School GPA 2014-2018')
ax2.set_title('Fall Semester Freshman Year GPA 2014-2018')

ax1.set_ylabel('Number of Students')
ax2.set_ylabel('Number of Students')

plt.savefig('images/gpa.png')
# Out:
# C:\Users\Kerry\Anaconda3\lib\site-packages\numpy\lib\histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Kerry\Anaconda3\lib\site-packages\numpy\lib\histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# ACT and SAT Scores
fig = plt.figure(figsize=(15,5))
plt.tight_layout()

ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.hist(df['ACT'])
ax2.hist(df['SAT Comp (new)'])

ax1.set_title('Student ACT Scores 2014-2018')
ax2.set_title('Student Total SAT Scores 2014-2018')

ax1.set_ylabel('Number of Students')
ax2.set_ylabel('Number of Students')

plt.savefig('images/standard_tests.png')

# %%
# SAT Score Breakdown
fig = plt.figure(figsize=(30,20))
plt.tight_layout()

ax1 = fig.add_subplot(2,3,1)
ax2 = fig.add_subplot(2,3,2)
ax3 = fig.add_subplot(2,3,3)

ax1.hist(df['SAT Comp (new)'])
ax2.hist(df['SAT Critical Reading (new)'])
ax3.hist(df['SAT Math (new)'])

ax1.set_title('Student Total SAT Scores 2014-2018')
ax2.set_title('Student SAT Critical Reading Scores 2014-2018')
ax3.set_title('Student SAT Math Scores 2014-2018')

ax1.set_ylabel('Number of Students')
ax2.set_ylabel('Number of Students')
ax3.set_ylabel('Number of Students')

plt.savefig('images/sat_breakdown.png')
